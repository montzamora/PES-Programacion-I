# %%
import pdb

# %%
def biseccion(f, a=-100, b=100, epsilon=0.001, max_iter=100):

    guess = (a + b) / 2

    # Contador de iteraciones
    num_guesses = 0
    
    pdb.set_trace()
    while abs(f(guess)) >= epsilon and num_guesses < max_iter:
        if f(a)*f(guess) > 0:
            # Si f(a) y f(guess) tienen el mismo signo, se debe
            # acortar el intervalo por la izquierda
            # Tu código acá:
            a = guess
        else:
            # De lo contrario, se acorta por el lado derecho
            # Tu código acá:
            b = guess
        # Siguiente guess en el punto medio del espacio de búsqueda
        guess = (a + b) / 2
        num_guesses += 1

    print('Iteraciones: ', num_guesses)
    print('Solución encontrada: f(%0.4f) = %0.4f' % (guess, f(guess)))
    return guess

# %%
f = lambda x: x**2 - x - 1
approx_phi = biseccion(f, a=1, b=2, epsilon=1e-6)
print(approx_phi)
# Out:
# > <ipython-input-2-6233292d0dfa>(9)biseccion()
# -> while abs(f(guess)) >= epsilon and num_guesses < max_iter:
# (Pdb) p guess
# 1.5
# (Pdb) p num_guesses
# 0
# (Pdb) where
#   c:\programdata\anaconda3\lib\runpy.py(193)_run_module_as_main()
# -> "__main__", mod_spec)
#   c:\programdata\anaconda3\lib\runpy.py(85)_run_code()
# -> exec(code, run_globals)
#   c:\programdata\anaconda3\lib\site-packages\ipykernel_launcher.py(16)<module>()
# -> app.launch_new_instance()
#   c:\programdata\anaconda3\lib\site-packages\traitlets\config\application.py(664)launch_instance()
# -> app.start()
#   c:\programdata\anaconda3\lib\site-packages\ipykernel\kernelapp.py(563)start()
# -> self.io_loop.start()
#   c:\programdata\anaconda3\lib\site-packages\tornado\platform\asyncio.py(148)start()
# -> self.asyncio_loop.run_forever()
#   c:\programdata\anaconda3\lib\asyncio\base_events.py(534)run_forever()
# -> self._run_once()
#   c:\programdata\anaconda3\lib\asyncio\base_events.py(1771)_run_once()
# -> handle._run()
#   c:\programdata\anaconda3\lib\asyncio\events.py(88)_run()
# -> self._context.run(self._callback, *self._args)
#   c:\programdata\anaconda3\lib\site-packages\tornado\ioloop.py(690)<lambda>()
# -> lambda f: self._run_callback(functools.partial(callback, future))
#   c:\programdata\anaconda3\lib\site-packages\tornado\ioloop.py(743)_run_callback()
# -> ret = callback()
#   c:\programdata\anaconda3\lib\site-packages\tornado\gen.py(787)inner()
# -> self.run()
#   c:\programdata\anaconda3\lib\site-packages\tornado\gen.py(748)run()
# -> yielded = self.gen.send(value)
#   c:\programdata\anaconda3\lib\site-packages\ipykernel\kernelbase.py(365)process_one()
# -> yield gen.maybe_future(dispatch(*args))
#   c:\programdata\anaconda3\lib\site-packages\tornado\gen.py(209)wrapper()
# -> yielded = next(result)
#   c:\programdata\anaconda3\lib\site-packages\ipykernel\kernelbase.py(272)dispatch_shell()
# -> yield gen.maybe_future(handler(stream, idents, msg))
#   c:\programdata\anaconda3\lib\site-packages\tornado\gen.py(209)wrapper()
# -> yielded = next(result)
#   c:\programdata\anaconda3\lib\site-packages\ipykernel\kernelbase.py(542)execute_request()
# -> user_expressions, allow_stdin,
#   c:\programdata\anaconda3\lib\site-packages\tornado\gen.py(209)wrapper()
# -> yielded = next(result)
#   c:\programdata\anaconda3\lib\site-packages\ipykernel\ipkernel.py(294)do_execute()
# -> res = shell.run_cell(code, store_history=store_history, silent=silent)
#   c:\programdata\anaconda3\lib\site-packages\ipykernel\zmqshell.py(536)run_cell()
# -> return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   c:\programdata\anaconda3\lib\site-packages\ipython\core\interactiveshell.py(2855)run_cell()
# -> raw_cell, store_history, silent, shell_futures)
#   c:\programdata\anaconda3\lib\site-packages\ipython\core\interactiveshell.py(2881)_run_cell()
# -> return runner(coro)
#   c:\programdata\anaconda3\lib\site-packages\ipython\core\async_helpers.py(68)_pseudo_sync_runner()
# -> coro.send(None)
#   c:\programdata\anaconda3\lib\site-packages\ipython\core\interactiveshell.py(3058)run_cell_async()
# -> interactivity=interactivity, compiler=compiler, result=result)
#   c:\programdata\anaconda3\lib\site-packages\ipython\core\interactiveshell.py(3249)run_ast_nodes()
# -> if (await self.run_code(code, result,  async_=asy)):
#   c:\programdata\anaconda3\lib\site-packages\ipython\core\interactiveshell.py(3326)run_code()
# -> exec(code_obj, self.user_global_ns, self.user_ns)
#   <ipython-input-3-108115f5a2b8>(2)<module>()
# -> approx_phi = biseccion(f, a=1, b=2, epsilon=1e-6)
# > <ipython-input-2-6233292d0dfa>(9)biseccion()
# -> while abs(f(guess)) >= epsilon and num_guesses < max_iter:
# (Pdb) max_iter
# 100
# (Pdb) epsilon
# 1e-06
# (Pdb) f(guess)
# -0.25
# (Pdb) n
# > <ipython-input-2-6233292d0dfa>(10)biseccion()
# -> if f(a)*f(guess) > 0:
# (Pdb) f(a)
# -1
# (Pdb) f(guess)
# -0.25
# (Pdb) f(a)*f(guess)>0
# True
# (Pdb) n
# > <ipython-input-2-6233292d0dfa>(14)biseccion()
# -> a = guess
# (Pdb) c
# Iteraciones:  16
# Solución encontrada: f(1.6180) = 0.0000
# 1.6180343627929688
